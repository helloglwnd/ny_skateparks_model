# %% [markdown]
# Importing libraries for classification and data cleaning

# %%
import os
import seaborn as sns 
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode
import matplotlib.pyplot as plt
from sklearn import ensemble, model_selection, metrics 
from sklearn import preprocessing
from sklearn.model_selection import train_test_split , cross_val_score , RandomizedSearchCV
import xgboost as xgb

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Adding and printing the dataframe with the skateparks

# %%
df=pd.read_csv('/content/skatepark_NY_data - DPR_Skateparks_001.csv')
df.head()
# Out:
#                                             the_geom                  SYSTEM  \
# 0  MULTIPOLYGON (((-73.91996794995724 40.58884837...    B057-06-SKATEPARK-01
# 1  MULTIPOLYGON (((-73.87144701429952 40.86716866...  X002-ZN03-SKATEPARK-01
# 2  MULTIPOLYGON (((-73.82910897363057 40.82693224...       X183-SKATEPARK-01
# 3  MULTIPOLYGON (((-73.92460034554938 40.83095313...       X034-SKATEPARK-01
# 4  MULTIPOLYGON (((-73.92708768919569 40.82560277...       X348-SKATEPARK-01
#
#   GISPROPNUM                           NAME  Google Rating BMX_PERMIT  \
# 0       B057          Marine Park Skatepark            4.2        NaN
# 1       X002           Bronx Park Skatepark            4.3        NaN
# 2       X183  Bruckner Playground Skatepark            3.9        NaN
# 3       X034              Mullaly Skatepark            4.3          Y
# 4       X348         River Avenue Skatepark            4.4          Y
#
#   INLINE_SKA SCOOTER_PE    FEATURES_1    FEATURES_2    FEATURES_3 PARK_SURFA  \
# 0        NaN        NaN        Funbox  Quarter Pipe     Bank Ramp   Concrete
# 1        NaN        NaN  Quarter Pipe        Funbox     Bank Ramp   Concrete
# 2        NaN        NaN        Funbox  Quarter Pipe     Bank Ramp   Concrete
# 3        NaN        NaN        Funbox     Half-Pipe  Quarter Pipe   Concrete
# 4          Y          Y        Funbox      Handrail         Ledge   Concrete
#
#   FEATURE_SU   BOROUGH    SHAPE_area   SHAPE_len
# 0       Wood  Brooklyn   6121.923885  337.738978
# 1      Metal     Bronx   6196.325183  319.055415
# 2   Concrete     Bronx   4935.574172  283.919460
# 3       Wood     Bronx  16409.661300  540.252203
# 4   Concrete     Bronx  16451.685880  529.498909

# %% [markdown]
# As we can see there are a lot of categorical values, in fact most of the features are categorical. For simplifying dealing with categoricals we can first copy them in a stand-alone dataframe```

# %%
df_cat = df.select_dtypes(include=['object']).copy()
df_cat.columns
# Out:
# Index(['the_geom', 'SYSTEM', 'GISPROPNUM', 'NAME', 'BMX_PERMIT', 'INLINE_SKA',
#        'SCOOTER_PE', 'FEATURES_1', 'FEATURES_2', 'FEATURES_3', 'PARK_SURFA',
#        'FEATURE_SU', 'BOROUGH'],
#       dtype='object')

# %% [markdown]
# It's also obvious that a lot of the categorical values lacking data - we'll populate them with the most popular and also logical variant - No data

# %%
df_cat[['BMX_PERMIT','INLINE_SKA','SCOOTER_PE']]=df[['BMX_PERMIT','INLINE_SKA','SCOOTER_PE']].replace(np.nan, 'N')
df_cat.head()
# Out:
#                                             the_geom                  SYSTEM  \
# 0  MULTIPOLYGON (((-73.91996794995724 40.58884837...    B057-06-SKATEPARK-01
# 1  MULTIPOLYGON (((-73.87144701429952 40.86716866...  X002-ZN03-SKATEPARK-01
# 2  MULTIPOLYGON (((-73.82910897363057 40.82693224...       X183-SKATEPARK-01
# 3  MULTIPOLYGON (((-73.92460034554938 40.83095313...       X034-SKATEPARK-01
# 4  MULTIPOLYGON (((-73.92708768919569 40.82560277...       X348-SKATEPARK-01
#
#   GISPROPNUM                           NAME BMX_PERMIT INLINE_SKA SCOOTER_PE  \
# 0       B057          Marine Park Skatepark          N          N          N
# 1       X002           Bronx Park Skatepark          N          N          N
# 2       X183  Bruckner Playground Skatepark          N          N          N
# 3       X034              Mullaly Skatepark          Y          N          N
# 4       X348         River Avenue Skatepark          Y          Y          Y
#
#      FEATURES_1    FEATURES_2    FEATURES_3 PARK_SURFA FEATURE_SU   BOROUGH
# 0        Funbox  Quarter Pipe     Bank Ramp   Concrete       Wood  Brooklyn
# 1  Quarter Pipe        Funbox     Bank Ramp   Concrete      Metal     Bronx
# 2        Funbox  Quarter Pipe     Bank Ramp   Concrete   Concrete     Bronx
# 3        Funbox     Half-Pipe  Quarter Pipe   Concrete       Wood     Bronx
# 4        Funbox      Handrail         Ledge   Concrete   Concrete     Bronx

# %% [markdown]
# We also don't need all of the categorical columns, so we'll save all the needed columns in the list and filter only columns belonging to that list

# %%
cat_columns=['BMX_PERMIT', 'INLINE_SKA',
       'SCOOTER_PE', 'FEATURES_1', 'FEATURES_2', 'FEATURES_3', 'PARK_SURFA',
       'FEATURE_SU', 'BOROUGH']
df_cat=df_cat[cat_columns]
df_cat.head()
# Out:
#   BMX_PERMIT INLINE_SKA SCOOTER_PE    FEATURES_1    FEATURES_2    FEATURES_3  \
# 0          N          N          N        Funbox  Quarter Pipe     Bank Ramp
# 1          N          N          N  Quarter Pipe        Funbox     Bank Ramp
# 2          N          N          N        Funbox  Quarter Pipe     Bank Ramp
# 3          Y          N          N        Funbox     Half-Pipe  Quarter Pipe
# 4          Y          Y          Y        Funbox      Handrail         Ledge
#
#   PARK_SURFA FEATURE_SU   BOROUGH
# 0   Concrete       Wood  Brooklyn
# 1   Concrete      Metal     Bronx
# 2   Concrete   Concrete     Bronx
# 3   Concrete       Wood     Bronx
# 4   Concrete   Concrete     Bronx

# %% [markdown]
# So now we have a good set of categorical columns with all data present everywhere. However, categorical values won't work in the model, so we'll need to transform them to numerical values. For that I'm going to use LabelEncoder module of preprocessing library

# %%
df_encoded=df_cat.apply(preprocessing.LabelEncoder().fit_transform)

# %% [markdown]
# Ok, so it seems that we have quite a good and clean set of Categorical type columns now. That's great! Now lets deal with the rest of the columns. But before we proceed I noticed an interesting thing that I wanted to action - "GEOM" column contains lattituds and lognitudes values that could be beneficial for features engineering. We need to process and save them in a stand alone list - in order to add to a resulting dataframe later

# %%
import re

lattitudes=[]
longitudes=[]
for x in df['the_geom']:
  text=x.replace('MULTIPOLYGON (((','MULTIPOLYGON')
  MATCH = re.search('MULTIPOLYGON(.+?), -', text)
  if MATCH:
    result_string = MATCH.group(1)
    lat=(result_string.rpartition(' ')[0])
    lon=(result_string.rpartition(' ')[2])
    lattitudes.append(float(lat[:7]))
    longitudes.append(float(lon[:6]))

# %% [markdown]
# Adding new geo location columns to the dataframe

# %%
df['lattitudes']=lattitudes
df['longitudes']=longitudes

# %% [markdown]
# All right, now let's have a look at the rest of the columns. I shortlisted attributes we really need and made a sub-dataframe of them which I called df_non_cat

# %%
df_non_cat=df[['NAME','Google Rating','SHAPE_area','SHAPE_len','lattitudes','longitudes']]

# %% [markdown]
# Now let's concatenate categorical and non-cat dataframe to get the resulting dataset

# %%
result_df=pd.concat([df_non_cat, df_encoded], axis=1, join='inner')

# %% [markdown]
# Voila! Now we have a clean and ready to process dataframe that we can use for a ML experiment

# %%
result_df.head()
# Out:
#                             NAME  Google Rating    SHAPE_area   SHAPE_len  \
# 0          Marine Park Skatepark            4.2   6121.923885  337.738978
# 1           Bronx Park Skatepark            4.3   6196.325183  319.055415
# 2  Bruckner Playground Skatepark            3.9   4935.574172  283.919460
# 3              Mullaly Skatepark            4.3  16409.661300  540.252203
# 4         River Avenue Skatepark            4.4  16451.685880  529.498909
#
#    lattitudes  longitudes  BMX_PERMIT  INLINE_SKA  SCOOTER_PE  FEATURES_1  \
# 0     -73.919      40.588           0           0           0           1
# 1     -73.871      40.867           0           0           0           5
# 2     -73.829      40.826           0           0           0           1
# 3     -73.924      40.830           1           0           0           1
# 4     -73.927      40.825           1           1           1           1
#
#    FEATURES_2  FEATURES_3  PARK_SURFA  FEATURE_SU  BOROUGH
# 0           5           0           1           2        1
# 1           1           0           1           1        0
# 2           5           0           1           0        0
# 3           2           5           1           2        0
# 4           3           4           1           0        0

# %% [markdown]
# ## Simple EDA with Folium and Plotly

# %% [markdown]
# Let's put our findins on the map! Folumn library provides an option to location of parks with the features in buble pop ups

# %%
# create map of New york skateparks using latitude and longitude values
import folium
map_ny_parks = folium.Map(location=[40.825,-73.927],zoom_start=7)

for lat, lng, label in zip(result_df['longitudes'], result_df['lattitudes'], df['FEATURES_1']):
    
    label_holder = folium.Popup(folium.IFrame(label, width=100, height=100), max_width=150)
    folium.CircleMarker(
        [lat, lng],
        radius=12,
        popup=label_holder,
        color='red',
        icon_color='green',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_ny_parks)

# %%
map_ny_parks
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script&gt;L_PREFER_CANVAS=false; L_NO_TOUCH=false; L_DISABLE_3D=false;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.4.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://rawcdn.githack.com/python-visualization/folium/master/folium/templates/leaflet.awesome.rotate.css&quot;/&gt;
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#
#     &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#         initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#     &lt;style&gt;#map_f6b72b12d4d53f1af9bac76c2e7564de {
#         position: relative;
#         width: 100.0%;
#         height: 100.0%;
#         left: 0.0%;
#         top: 0.0%;
#         }
#     &lt;/style&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div class=&quot;folium-map&quot; id=&quot;map_f6b72b12d4d53f1af9bac76c2e7564de&quot; &gt;&lt;/div&gt;
# &lt;/body&gt;
# &lt;script&gt;
#
#
#         var bounds = null;
#
#
#     var map_f6b72b12d4d53f1af9bac76c2e7564de = L.map(
#         &#x27;map_f6b72b12d4d53f1af9bac76c2e7564de&#x27;, {
#         center: [40.825, -73.927],
#         zoom: 7,
#         maxBounds: bounds,
#         layers: [],
#         worldCopyJump: false,
#         crs: L.CRS.EPSG3857,
#         zoomControl: true,
#         });
#
#
#
#     var tile_layer_d9d64074a3adb0e17c775f86f1962525 = L.tileLayer(
#         &#x27;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&#x27;,
#         {
#         &quot;attribution&quot;: null,
#         &quot;detectRetina&quot;: false,
#         &quot;maxNativeZoom&quot;: 18,
#         &quot;maxZoom&quot;: 18,
#         &quot;minZoom&quot;: 0,
#         &quot;noWrap&quot;: false,
#         &quot;opacity&quot;: 1,
#         &quot;subdomains&quot;: &quot;abc&quot;,
#         &quot;tms&quot;: false
# }).addTo(map_f6b72b12d4d53f1af9bac76c2e7564de);
#
#             var circle_marker_b398757811cadd027706930792fdb306 = L.circleMarker(
#                 [40.588, -73.919],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 12,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_f6b72b12d4d53f1af9bac76c2e7564de);
#
#
#             var popup_7d485723d42515bc71ef330d5c9aff31 = L.popup({maxWidth: &#x27;150&#x27;
#
#             });
#
#
#                 var i_frame_107c7c5b3fc3c5ece37de49cb1a8f9cb = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBGdW5ib3g=&quot; width=&quot;100&quot; style=&quot;border:none !important;&quot; height=&quot;100&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_7d485723d42515bc71ef330d5c9aff31.setContent(i_frame_107c7c5b3fc3c5ece37de49cb1a8f9cb);
#
#
#             circle_marker_b398757811cadd027706930792fdb306.bindPopup(popup_7d485723d42515bc71ef330d5c9aff31)
#             ;
#
#
#
#
#             var circle_marker_7a2e312823fd8658bf11ea931734104f = L.circleMarker(
#                 [40.867, -73.871],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 12,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_f6b72b12d4d53f1af9bac76c2e7564de);
#
#
#             var popup_d828f4b9a7e0bd862f964ea45c6ff5b5 = L.popup({maxWidth: &#x27;150&#x27;
#
#             });
#
#
#                 var i_frame_2b7704c3c7350e4064502c521e1dada8 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBRdWFydGVyIFBpcGU=&quot; width=&quot;100&quot; style=&quot;border:none !important;&quot; height=&quot;100&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_d828f4b9a7e0bd862f964ea45c6ff5b5.setContent(i_frame_2b7704c3c7350e4064502c521e1dada8);
#
#
#             circle_marker_7a2e312823fd8658bf11ea931734104f.bindPopup(popup_d828f4b9a7e0bd862f964ea45c6ff5b5)
#             ;
#
#
#
#
#             var circle_marker_81541e088dd9f7c3423e26760495517a = L.circleMarker(
#                 [40.826, -73.829],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;opacity&quot;: 1.0,
#   &quot;radius&quot;: 12,
#   &quot;stroke&quot;: true,
#   &quot;weight&quot;: 3
# }
#                 )
#                 .addTo(map_f6b72b12d4d53f1af9bac76c2e7564de);
#
#
#             var popup_20318e603f229446ec8644fb3b1332b9 = L.popup({maxWidth: &#x27;150&#x27;
#
#             });
#
#
#                 var i_frame_a49c72d67a0be226efe9f23034bdeb08 = $(`&lt;iframe src=&quot;data:text/html;charset=utf-8;base64,CiAgICBGdW5ib3g=&quot; width=&quot;100&quot; style=&quot;border:none !important;&quot; height=&quot;100&quot;&gt;&lt;/iframe&gt;`)[0];
#                 popup_20318e603f229446ec8644fb3b1332b9.setContent(i_frame_a49c72d67a0be226efe9f23034bdeb08);
#
#
#             circle_marker_81541e088dd9f7c3423e26760495517a.bindPopup(popup_20318e603f229446ec8644fb3b1332b9)
#             ;
#
#
#
#
#             var circle_marker_ac3ad7b2c04f158b7a28083c6f1f4ba9 = L.circleMarker(
#                 [40.83, -73.924],
#                 {
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;color&quot;: &quot;red&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3186cc&quot;,
#   &quot;fillOpacity&quot;: 0.7,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quo

# %% [markdown]
# Let's also look at how we can perform a simple EDA on core features. First of all we are interested in if having enough features helps get higher rating. for that I'm using Plotly Express library

# %%
import plotly.express as px
# df = px.data.tips()
fig = px.histogram(df, x="NAME", y="Google Rating", color="FEATURES_1",
                   marginal="box", 
                   hover_data=df.columns)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="5d5e9a24-9127-4c5d-8dd3-d15beeb459db" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5d5e9a24-9127-4c5d-8dd3-d15beeb459db")) {                    Plotly.newPlot(                        "5d5e9a24-9127-4c5d-8dd3-d15beeb459db",                        [{"alignmentgroup":"True","bingroup":"x","histfunc":"sum","hovertemplate":"FEATURES_1=Funbox<br>NAME=%{x}<br>sum of Google Rating=%{y}<extra></extra>","legendgroup":"Funbox","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Funbox","offsetgroup":"Funbox","orientation":"v","showlegend":true,"x":["Marine Park Skatepark","Bruckner Playground Skatepark","Mullaly Skatepark","River Avenue Skatepark","Forest Park Skatepark","Coleman Skatepark","Ben Soto Skatepark","London Planetree Playground","Washington Park Skatepark"],"xaxis":"x","y":[4.2,3.9,4.3,4.4,4.2,4.5,3.8,4.3,3.9],"yaxis":"y","type":"histogram"},{"alignmentgroup":"True","customdata":[["MULTIPOLYGON (((-73.91996794995724 40.588848379685274, -73.91996219041039 40.58885629235341, -73.91995483241764 40.58886339336753, -73.91994606859664 40.58886949683679, -73.91993612836707 40.58887444298401, -73.91992527194493 40.5888781023285, -73.91991378353059 40.58888037907563, -73.9199019638688 40.588881213624475, -73.91988126684772 40.588881825932255, -73.91986094669114 40.58888488513245, -73.91984149808071 40.58889031675072, -73.91982339448106 40.58889798855772, -73.91980707661376 40.58890771378796, -73.919796683358 40.58891602161859, -73.919784636384 40.58892291021433, -73.91977126507811 40.58892819122813, -73.91975693503676 40.58893172026706, -73.91974203807018 40.58893340084064, -73.91975058272715 40.58897510285266, -73.91972659286603 40.58897517446579, -73.91970294990821 40.588972074719145, -73.91968036972415 40.58896589746802, -73.91965953600473 40.588956829749584, -73.91964107956014 40.58894514611947, -73.91962555921972 40.58893120033879, -73.91961344491156 40.58891541466253, -73.91960510343398 40.588898267054375, -73.91960078734971 40.588880276714605, -73
"y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"p ...

# %% [markdown]
# This can be solved if we 'melt' dataframe - that means 'unpivoting' it to a narrower formats. likely there is a built - in pandas function for that

# %%
df_melted=pd.melt(df, id_vars=['NAME'], value_vars=['FEATURES_1','FEATURES_2','FEATURES_3'])

# %%
df_melted.sort_values(by=['NAME']).head()
# Out:
#                        NAME    variable         value
# 32  12th & A/Open Road Park  FEATURES_2         Ledge
# 12  12th & A/Open Road Park  FEATURES_1         Ledge
# 52  12th & A/Open Road Park  FEATURES_3  Quarter Pipe
# 29   Astoria Park Skatepark  FEATURES_2     Bank Ramp
# 9    Astoria Park Skatepark  FEATURES_1         Ledge

# %%
melted_df_with_rating=df_melted.merge(result_df, on='NAME', how='left')

# %% [markdown]
# Now that we have nice and clean melted database we can build some more sophisticated boxplots like the ones below

# %%
fig = px.box(melted_df_with_rating, y="Google Rating", color="value", facet_col="value", 
              points='all', boxmode='overlay')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="344fa4d4-8d18-475c-b1e8-6b5a1e9e07c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("344fa4d4-8d18-475c-b1e8-6b5a1e9e07c7")) {                    Plotly.newPlot(                        "344fa4d4-8d18-475c-b1e8-6b5a1e9e07c7",                        [{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"value=Funbox<br>Google Rating=%{y}<extra></extra>","legendgroup":"Funbox","marker":{"color":"#636efa"},"name":"Funbox","notched":false,"offsetgroup":"Funbox","orientation":"v","showlegend":true,"x0":" ","xaxis":"x","y":[4.2,3.9,4.3,4.4,4.2,4.5,3.8,4.3,3.9,4.3,4.5,4.5,4.0],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"value=Quarter Pipe<br>Google Rating=%{y}<extra></extra>","legendgroup":"Quarter Pipe","marker":{"color":"#EF553B"},"name":"Quarter Pipe","notched":false,"offsetgroup":"Quarter Pipe","orientation":"v","showlegend":true,"x0":" ","xaxis":"x2","y":[4.3,4.6,4.2,3.9,4.0,3.8,4.3,4.3,4.5,4.2,4.0,4.4,4.5],"y0":" ","yaxis":"y2","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"value=Bowl/Pool<br>Google Rating=%{y}<extra></extra>","legendgroup":"Bowl/Pool","marker":{"color":"#00cc96"},"name":"Bowl/Pool","notched":false,"offsetgroup":"Bowl/Pool","orientation":"v","showlegend":true,"x0":" ","xaxis":"x3","y":[4.5,3.8],"y0":" ","yaxis":"y3","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"value=Handrail<br>Google Rating=%{y}<extra></extra>","legendgroup":"Handrail","marker":{"color":"#ab63fa"},"name":"Handrail","notched":false,"offsetgroup":"Handrail","orientation":"v","showlegend":true,"x0":" ","xaxis":"x4","y":[4.5,4.6,4.4,4.4,4.3],"y0":" ","yaxis":"y4","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"value=Ledge<br>Google Rating=%{y}<extra></extra>","legendgroup":"Ledge","marker":{"color":"#FFA15A"},"name":"Ledge","notched":false,"offsetgroup":"Ledge","orientation":"v","showlegend":true,"x0":" ","xaxis":"x5","y":[2.0,4.5,4.0,4.4,4.5,4.5,2.0,4.6,4.0,4.6,3.9,4.4,4.5,4.5],"y0":" ","yaxis":"y5","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"value=Half-Pipe<br>Google Rating=%{y}<extra></extra>","legendgroup":"Half-Pipe","marker":{"color":"#19d3f3"},"name":"Half-Pipe","notched":false,"offsetgroup":"Half-Pipe","orientation":"v","showlegend":true,"x0":" ","xaxis":"x6","y":[4.0,4.3],"y0":" ","yaxis":"y6","type":"box"},{"alignmentgroup":"True","boxpoints":"all","hovertemplate":"value=Bank Ramp<br>Google Rating=%{y}<extra></extra>","legendgroup":"Bank Ramp","marker":{"color":"#FF6692"},"name":"Bank Ramp","notched":false,"offsetgroup":"Bank Ramp","orientation":"v","showlegend":true,"x0":" ","xaxis":"x7","y":[4.5,4.2,4.5,4.2,4.3,3.9,4.5,2.0,4.6,4.6,3.9],"y0":" ","yaxis":"y7","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...

# %% [markdown]
# Lets do the same for "permit" columns - now they re distributed accorss 3 attirbutes

# %%
df_melted_permit=pd.melt(df, id_vars=['NAME'], value_vars=['BMX_PERMIT','INLINE_SKA','SCOOTER_PE'])
df_melted_permit=df_melted_permit.merge(result_df, on='NAME', how='left')

# %%
df_melted_permit.head()
# Out:
#                             NAME    variable value  Google Rating  \
# 0          Marine Park Skatepark  BMX_PERMIT   NaN            4.2
# 1           Bronx Park Skatepark  BMX_PERMIT   NaN            4.3
# 2  Bruckner Playground Skatepark  BMX_PERMIT   NaN            3.9
# 3              Mullaly Skatepark  BMX_PERMIT     Y            4.3
# 4         River Avenue Skatepark  BMX_PERMIT     Y            4.4
#
#      SHAPE_area   SHAPE_len  lattitudes  longitudes  BMX_PERMIT  INLINE_SKA  \
# 0   6121.923885  337.738978     -73.919      40.588           0           0
# 1   6196.325183  319.055415     -73.871      40.867           0           0
# 2   4935.574172  283.919460     -73.829      40.826           0           0
# 3  16409.661300  540.252203     -73.924      40.830           1           0
# 4  16451.685880  529.498909     -73.927      40.825           1           1
#
#    SCOOTER_PE  FEATURES_1  FEATURES_2  FEATURES_3  PARK_SURFA  FEATURE_SU  \
# 0           0           1           5           0           1           2
# 1           0           5           1           0           1           1
# 2           0           1           5           0           1           0
# 3           0           1           2           5           1           2
# 4           1           1           3           4           1           0
#
#    BOROUGH
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0

# %%
df_melted_permit['value']=df_melted_permit['value'].replace(np.nan, 'N')

# %%
import plotly.express as px
fig = px.box(df_melted_permit, x="variable", y="Google Rating", color="value",
             notched=True, # used notched shape
             hover_data=["NAME"], points='all' # add day column to hover data
            )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="87fdf30a-d6a2-42b9-aeb0-9624fc18c8c3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("87fdf30a-d6a2-42b9-aeb0-9624fc18c8c3")) {                    Plotly.newPlot(                        "87fdf30a-d6a2-42b9-aeb0-9624fc18c8c3",                        [{"alignmentgroup":"True","boxpoints":"all","customdata":[["Marine Park Skatepark"],["Bronx Park Skatepark"],["Bruckner Playground Skatepark"],["McCarren Park Skatepark"],["Thomas Greene Skate Spot"],["Flushing Meadows Maloof Skate Plaza"],["Astoria Park Skatepark"],["Forest Park Skatepark"],["Coleman Skatepark"],["12th & A/Open Road Park"],["Riverside Park Skatepark"],["Canarsie Skatepark"],["Far Rockaway Skatepark"],["Washington Park Skatepark"],["Marine Park Skatepark"],["Bronx Park Skatepark"],["Bruckner Playground Skatepark"],["Mullaly Skatepark"],["Owl's Head Millenium Skatepark"],["McCarren Park Skatepark"],["Thomas Greene Skate Spot"],["Astoria Park Skatepark"],["12th & A/Open Road Park"],["Canarsie Skatepark"],["Robert Venable Skatepark"],["Washington Park Skatepark"],["Marine Park Skatepark"],["Bronx Park Skatepark"],["Bruckner Playground Skatepark"],["Mullaly Skatepark"],["Owl's Head Millenium Skatepark"],["McCarren Park Skatepark"],["Thomas Greene Skate Spot"],["Astoria Park Skatepark"],["Coleman Skatepark"],["12th & A/Open Road Park"],["Riverside Park Skatepark"],["Canarsie Skatepark"],["Robert Venable Skatepark"],["Washington Park Skatepark"]],"hovertemplate":"value=N<br>variable=%{x}<br>Google Rating=%{y}<br>NAME=%{customdata[0]}<extra></extra>","legendgroup":"N","marker":{"color":"#636efa"},"name":"N","notched":true,"offsetgroup":"N","orientation":"v","showlegend":true,"x":["BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE"],"x0":" ","xaxis":"x","y":[4.2,4.3,3.9,4.5,2.0,4.6,4.5,4.2,4.5,4.0,4.0,4.4,4.5,3.9,4.2,4.3,3.9,4.3,4.5,4.5,2.0,4.5,4.0,4.4,4.6,3.9,4.2,4.3,3.9,4.3,4.5,4.5,2.0,4.5,4.5,4.0,4.0,4.4,4.6,3.9],"y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","boxpoints":"all","customdata":[["Mullaly Skatepark"],["River Avenue Skatepark"],["Owl's Head Millenium Skatepark"],["Ben Soto Skatepark"],["Robert Venable Skatepark"],["London Planetree Playground"],["River Avenue Skatepark"],["Flushing Meadows Maloof Skate Plaza"],["Forest Park Skatepark"],["Coleman Skatepark"],["Riverside Park Skatepark"],["Ben Soto Skatepark"],["London Planetree Playground"],["Far Rockaway Skatepark"],["River Avenue Skatepark"],["Flushing Meadows Maloof Skate Plaza"],["Forest Park Skatepark"],["Ben Soto Skatepark"],["London Planetree Playground"],["Far Rockaway Skatepark"]],"hovertemplate":"value=Y<br>variable=%{x}<br>Google Rating=%{y}<br>NAME=%{customdata[0]}<extra></extra>","legendgroup":"Y","marker":{"color":"#EF553B"},"name":"Y","notched":true,"offsetgroup":"Y","orientation":"v","showlegend":true,"x":["BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","BMX_PERMIT","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","INLINE_SKA","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE","SCOOTER_PE"],"x0":" ","xaxis":"x","y":[4.3,4.4,4.5,3.8,4.6,4.3,4.4,4.6,4.2,4.5,4.0,3.8,4.3,4.5,4.4,4.6,4.2,3.8,4.3,4.5],"y0":" ","yaxis":"y","type":"box"}],                        {"temp ...

# %% [markdown]
# Finally let's see how continuos features correlate with each other. For that we'll be using a scatterplot. I thought it would be intersting to also introduce a new feature that counts a number of permits for every sktepark

# %%
df['number_of_permits']=result_df['BMX_PERMIT']+result_df['INLINE_SKA']+result_df['SCOOTER_PE']

# %%
import plotly.express as px
fig = px.scatter_matrix(df, dimensions=["SHAPE_area", "SHAPE_len", "Google Rating", "number_of_permits"],
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="3df8c79e-4927-4e50-a366-36e09f33609a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3df8c79e-4927-4e50-a366-36e09f33609a")) {                    Plotly.newPlot(                        "3df8c79e-4927-4e50-a366-36e09f33609a",                        [{"dimensions":[{"axis":{"matches":true},"label":"SHAPE_area","values":[6121.923885,6196.325183,4935.574172,16409.6613,16451.68588,15166.99785,9340.832315,7503.410025,15975.27077,18061.19673,14367.29104,35531.60109,11486.00212,41629.74567,15219.31379,17054.75023,923.1828736,12232.5221,15666.7812,14438.15786]},{"axis":{"matches":true},"label":"SHAPE_len","values":[337.7389784,319.0554146,283.9194599,540.2522026,529.4989093,576.2386065,480.603473,348.1139325,448.6227065,497.5254964,487.0174396,908.1849634,516.4720923,879.5985055,1429.342861,574.2779228,143.7226951,440.1047681,566.5503753,541.573191]},{"axis":{"matches":true},"label":"Google Rating","values":[4.2,4.3,3.9,4.3,4.4,4.5,4.5,2.0,4.6,4.5,4.2,4.5,4.0,4.0,4.4,3.8,4.6,4.3,4.5,3.9]},{"axis":{"matches":true},"label":"number_of_permits","values":[0,0,0,1,3,1,0,0,2,0,2,1,0,1,0,3,1,3,2,0]}],"hovertemplate":"%{xaxis.title.text}=%{x}<br>%{yaxis.title.text}=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"name":"","showlegend":false,"type":"splom"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}] ...

# %% [markdown]
# However we see that neither skatepark area no number of permits correlate with the rating
