# %% [markdown]
# Importing libraries for classification and data cleaning

# %%
import os
import seaborn as sns 
import numpy as np
import pandas as pd
from pathlib import Path
from tqdm import tqdm
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from plotly.offline import init_notebook_mode
import matplotlib.pyplot as plt
from sklearn import ensemble, model_selection, metrics 
from sklearn import preprocessing
from sklearn.model_selection import train_test_split , cross_val_score , RandomizedSearchCV
import xgboost as xgb

# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Adding and printing the dataframe with the skateparks

# %%
df=pd.read_csv('/content/skatepark_NY_data - DPR_Skateparks_001.csv')
df.head()
# Out:
#                                             the_geom                  SYSTEM  \
# 0  MULTIPOLYGON (((-73.91996794995724 40.58884837...    B057-06-SKATEPARK-01
# 1  MULTIPOLYGON (((-73.87144701429952 40.86716866...  X002-ZN03-SKATEPARK-01
# 2  MULTIPOLYGON (((-73.82910897363057 40.82693224...       X183-SKATEPARK-01
# 3  MULTIPOLYGON (((-73.92460034554938 40.83095313...       X034-SKATEPARK-01
# 4  MULTIPOLYGON (((-73.92708768919569 40.82560277...       X348-SKATEPARK-01
#
#   GISPROPNUM                           NAME  Google Rating BMX_PERMIT  \
# 0       B057          Marine Park Skatepark            4.2        NaN
# 1       X002           Bronx Park Skatepark            4.3        NaN
# 2       X183  Bruckner Playground Skatepark            3.9        NaN
# 3       X034              Mullaly Skatepark            4.3          Y
# 4       X348         River Avenue Skatepark            4.4          Y
#
#   INLINE_SKA SCOOTER_PE    FEATURES_1    FEATURES_2    FEATURES_3 PARK_SURFA  \
# 0        NaN        NaN        Funbox  Quarter Pipe     Bank Ramp   Concrete
# 1        NaN        NaN  Quarter Pipe        Funbox     Bank Ramp   Concrete
# 2        NaN        NaN        Funbox  Quarter Pipe     Bank Ramp   Concrete
# 3        NaN        NaN        Funbox     Half-Pipe  Quarter Pipe   Concrete
# 4          Y          Y        Funbox      Handrail         Ledge   Concrete
#
#   FEATURE_SU   BOROUGH    SHAPE_area   SHAPE_len
# 0       Wood  Brooklyn   6121.923885  337.738978
# 1      Metal     Bronx   6196.325183  319.055415
# 2   Concrete     Bronx   4935.574172  283.919460
# 3       Wood     Bronx  16409.661300  540.252203
# 4   Concrete     Bronx  16451.685880  529.498909

# %% [markdown]
# As we can see there are a lot of categorical values, in fact most of the features are categorical. For simplifying dealing with categoricals we can first copy them in a stand-alone dataframe```

# %%
df_cat = df.select_dtypes(include=['object']).copy()
df_cat.columns
# Out:
# Index(['the_geom', 'SYSTEM', 'GISPROPNUM', 'NAME', 'BMX_PERMIT', 'INLINE_SKA',
#        'SCOOTER_PE', 'FEATURES_1', 'FEATURES_2', 'FEATURES_3', 'PARK_SURFA',
#        'FEATURE_SU', 'BOROUGH'],
#       dtype='object')

# %% [markdown]
# It's also obvious that a lot of the categorical values lacking data - we'll populate them with the most popular and also logical variant - No data

# %%
df_cat[['BMX_PERMIT','INLINE_SKA','SCOOTER_PE']]=df[['BMX_PERMIT','INLINE_SKA','SCOOTER_PE']].replace(np.nan, 'N')
df_cat.head()
# Out:
#                                             the_geom                  SYSTEM  \
# 0  MULTIPOLYGON (((-73.91996794995724 40.58884837...    B057-06-SKATEPARK-01
# 1  MULTIPOLYGON (((-73.87144701429952 40.86716866...  X002-ZN03-SKATEPARK-01
# 2  MULTIPOLYGON (((-73.82910897363057 40.82693224...       X183-SKATEPARK-01
# 3  MULTIPOLYGON (((-73.92460034554938 40.83095313...       X034-SKATEPARK-01
# 4  MULTIPOLYGON (((-73.92708768919569 40.82560277...       X348-SKATEPARK-01
#
#   GISPROPNUM                           NAME BMX_PERMIT INLINE_SKA SCOOTER_PE  \
# 0       B057          Marine Park Skatepark          N          N          N
# 1       X002           Bronx Park Skatepark          N          N          N
# 2       X183  Bruckner Playground Skatepark          N          N          N
# 3       X034              Mullaly Skatepark          Y          N          N
# 4       X348         River Avenue Skatepark          Y          Y          Y
#
#      FEATURES_1    FEATURES_2    FEATURES_3 PARK_SURFA FEATURE_SU   BOROUGH
# 0        Funbox  Quarter Pipe     Bank Ramp   Concrete       Wood  Brooklyn
# 1  Quarter Pipe        Funbox     Bank Ramp   Concrete      Metal     Bronx
# 2        Funbox  Quarter Pipe     Bank Ramp   Concrete   Concrete     Bronx
# 3        Funbox     Half-Pipe  Quarter Pipe   Concrete       Wood     Bronx
# 4        Funbox      Handrail         Ledge   Concrete   Concrete     Bronx

# %% [markdown]
# We also don't need all of the categorical columns, so we'll save all the needed columns in the list and filter only columns belonging to that list

# %%
cat_columns=['BMX_PERMIT', 'INLINE_SKA',
       'SCOOTER_PE', 'FEATURES_1', 'FEATURES_2', 'FEATURES_3', 'PARK_SURFA',
       'FEATURE_SU', 'BOROUGH']
df_cat=df_cat[cat_columns]
df_cat.head()
# Out:
#   BMX_PERMIT INLINE_SKA SCOOTER_PE    FEATURES_1    FEATURES_2    FEATURES_3  \
# 0          N          N          N        Funbox  Quarter Pipe     Bank Ramp
# 1          N          N          N  Quarter Pipe        Funbox     Bank Ramp
# 2          N          N          N        Funbox  Quarter Pipe     Bank Ramp
# 3          Y          N          N        Funbox     Half-Pipe  Quarter Pipe
# 4          Y          Y          Y        Funbox      Handrail         Ledge
#
#   PARK_SURFA FEATURE_SU   BOROUGH
# 0   Concrete       Wood  Brooklyn
# 1   Concrete      Metal     Bronx
# 2   Concrete   Concrete     Bronx
# 3   Concrete       Wood     Bronx
# 4   Concrete   Concrete     Bronx

# %% [markdown]
# So now we have a good set of categorical columns with all data present everywhere. However, categorical values won't work in the model, so we'll need to transform them to numerical values. For that I'm going to use LabelEncoder module of preprocessing library

# %%
df_encoded=df_cat.apply(preprocessing.LabelEncoder().fit_transform)

# %% [markdown]
# Ok, so it seems that we have quite a good and clean set of Categorical type columns now. That's great! Now lets deal with the rest of the columns. But before we proceed I noticed an interesting thing that I wanted to action - "GEOM" column contains lattituds and lognitudes values that could be beneficial for features engineering. We need to process and save them in a stand alone list - in order to add to a resulting dataframe later

# %%
import re

lattitudes=[]
longitudes=[]
for x in df['the_geom']:
  text=x.replace('MULTIPOLYGON (((','MULTIPOLYGON')
  MATCH = re.search('MULTIPOLYGON(.+?), -', text)
  if MATCH:
    result_string = MATCH.group(1)
    lat=(result_string.rpartition(' ')[0])
    lon=(result_string.rpartition(' ')[2])
    lattitudes.append(float(lat[:7]))
    longitudes.append(float(lon[:6]))

# %% [markdown]
# Adding new geo location columns to the dataframe

# %%
df['lattitudes']=lattitudes
df['longitudes']=longitudes

# %% [markdown]
# All right, now let's have a look at the rest of the columns. I shortlisted attributes we really need and made a sub-dataframe of them which I called df_non_cat

# %%
df_non_cat=df[['NAME','Google Rating','SHAPE_area','SHAPE_len','lattitudes','longitudes']]

# %% [markdown]
# Now let's concatenate categorical and non-cat dataframe to get the resulting dataset

# %%
result_df=pd.concat([df_non_cat, df_encoded], axis=1, join='inner')

# %% [markdown]
# Voila! Now we have a clean and ready to process dataframe that we can use for a ML experiment

# %%
result_df.head()
# Out:
#                             NAME  Google Rating    SHAPE_area   SHAPE_len  \
# 0          Marine Park Skatepark            4.2   6121.923885  337.738978
# 1           Bronx Park Skatepark            4.3   6196.325183  319.055415
# 2  Bruckner Playground Skatepark            3.9   4935.574172  283.919460
# 3              Mullaly Skatepark            4.3  16409.661300  540.252203
# 4         River Avenue Skatepark            4.4  16451.685880  529.498909
#
#    lattitudes  longitudes  BMX_PERMIT  INLINE_SKA  SCOOTER_PE  FEATURES_1  \
# 0     -73.919      40.588           0           0           0           1
# 1     -73.871      40.867           0           0           0           5
# 2     -73.829      40.826           0           0           0           1
# 3     -73.924      40.830           1           0           0           1
# 4     -73.927      40.825           1           1           1           1
#
#    FEATURES_2  FEATURES_3  PARK_SURFA  FEATURE_SU  BOROUGH
# 0           5           0           1           2        1
# 1           1           0           1           1        0
# 2           5           0           1           0        0
# 3           2           5           1           2        0
# 4           3           4           1           0        0
